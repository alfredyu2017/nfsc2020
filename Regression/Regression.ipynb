# %% [markdown]
# # Requirements
# * bigWigAverageOverBed (hgdownload.soe.ucsc.edu/admin/exe/. Make sure it is executable and in the $PATH.)
# * numpy
# * matplotlib
# * tensorflow
# * keras
# * sklearn

# %% [markdown]
# # Data Source
# * Download http://hgdownload.soe.ucsc.edu/gbdb/hg19/bbi/wgEncodeOpenChromDnaseNhekSig.bigWig

# %%
# generate 100bp bin bed file
# !awk 'BEGIN{x=0; id=1}{while(x+bin <= $2) {print $1"\t"x"\t"x+bin-1"\t"id; x+=bin; id+=1}x=0}' \
bin=100 hg19_chr.lengths > hg19_100b_bins.bed

# %%
# generate average score of Dnase bigwig over 100b bed
# !bigWigAverageOverBed ./wgEncodeOpenChromDnaseNhekSig.bigWig ./hg19_100b_bins.bed ./Dnase.tab
# Out:
# processing chromosomes.......................

# %%
# normalize the Dnase data
import numpy as np
from math import pi
from numpy import arctan
from scipy.stats import iqr

epidata = np.loadtxt('Dnase.tab', usecols=(3))
Q3 = np.quantile(epidata, 0.75)
epidata = epidata/(Q3+1.5*iqr(epidata))
epidata = 2*arctan(epidata)/pi

inputstart = 0
inputstop = 0
outputstart = 0
outputstop = 0
m = np.zeros((61903, 500))
with open('hg19_chr.lengths') as chr:
    for line in chr:
        chrom, chrlength = line.split()
        chrlength = int(chrlength)
        inputstart = inputstop
        inputstop = inputstop + chrlength//100
        outputstart = outputstop
        outputstop = outputstop + chrlength//50000
        for j in range(outputstart, outputstop):
            m[j, :] = epidata[inputstart:inputstart+500]
            inputstart += 500
    np.save('Dnase_norm', m)

# %%
# normalize the DSB data
dsbdata = np.loadtxt('NHEK_BREAK_50kb.bedgraph', usecols=(3))
Q3 = np.quantile(dsbdata, 0.75)
dsbdata = dsbdata/(Q3+1.5*iqr(dsbdata))
dsbdata = 2*arctan(dsbdata)/pi

np.save('DSB_norm', dsbdata)

# %%
# training
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Conv1D
from keras.layers import MaxPool1D, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import initializers
import sklearn.metrics
import os
os.mkdir('model')

model = Sequential()
model.add(Conv1D(32, 3, activation = 'relu', input_shape = (500,1), kernel_initializer=initializers.Ones()))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Conv1D(32, 3, activation = 'relu', kernel_initializer=initializers.Ones()))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Conv1D(32, 3, activation = 'relu', kernel_initializer=initializers.Ones()))
model.add(BatchNormalization())
model.add(MaxPool1D(2))
model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1))
model.summary()

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

x =np.load('Dnase_norm.npy')
x = x[:,:,np.newaxis].astype('float32')
y = np.load('DSB_norm.npy').astype('float32')
checkpoint = ModelCheckpoint('model/' + 'aaa', monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_monitor = EarlyStopping(monitor='val_loss', patience = 5)
history = model.fit(x, y, epochs=50, batch_size=128, verbose=1, validation_split=0.2, callbacks=[checkpoint, early_stopping_monitor])
y_pred = model.predict(x, verbose=1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 498, 32)           128
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 498, 32)           128
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 249, 32)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 247, 32)           3104
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 247, 32)           128
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 123, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 121, 32)           3104
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 121, 32)           128
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 60, 32)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                61472
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 68,225
# Trainable params: 68,033
# Non-trainable params: 192
# _________________________________________________________________
# Train on 49522 samples, validate on 12381 samples
# Epoch 1/50
# 49522/49522 [==============================] - 69s 1ms/step - loss: 2.0521 - mae: 0.8276 - val_loss: 0.6437 - val_mae: 0.6591
#
# Epoch 00001: val_loss improved from inf to 0.64374, saving model to model/aaa
# Epoch 2/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0658 - mae: 0.1451 - val_loss: 0.0129 - val_mae: 0.0895
#
# Epoch 00002: val_loss improved from 0.64374 to 0.01289, saving model to model/aaa
# Epoch 3/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0062 - mae: 0.0566 - val_loss: 0.0117 - val_mae: 0.0871
#
# Epoch 00003: val_loss improved from 0.01289 to 0.01172, saving model to model/aaa
# Epoch 4/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0051 - mae: 0.0508 - val_loss: 0.0212 - val_mae: 0.1205
#
# Epoch 00004: val_loss did not improve from 0.01172
# Epoch 5/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0042 - mae: 0.0460 - val_loss: 0.0120 - val_mae: 0.0845
#
# Epoch 00005: val_loss did not improve from 0.01172
# Epoch 6/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0034 - mae: 0.0397 - val_loss: 0.0101 - val_mae: 0.0764
#
# Epoch 00006: val_loss improved from 0.01172 to 0.01012, saving model to model/aaa
# Epoch 7/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0080 - val_mae: 0.0695
#
# Epoch 00007: val_loss improved from 0.01012 to 0.00802, saving model to model/aaa
# Epoch 8/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0022 - mae: 0.0324 - val_loss: 0.0080 - val_mae: 0.0641
#
# Epoch 00008: val_loss improved from 0.00802 to 0.00799, saving model to model/aaa
# Epoch 9/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0021 - mae: 0.0316 - val_loss: 0.0084 - val_mae: 0.0612
#
# Epoch 00009: val_loss did not improve from 0.00799
# Epoch 10/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0022 - mae: 0.0307 - val_loss: 0.0079 - val_mae: 0.0615
#
# Epoch 00010: val_loss improved from 0.00799 to 0.00794, saving model to model/aaa
# Epoch 11/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0020 - mae: 0.0302 - val_loss: 0.0084 - val_mae: 0.0651
#
# Epoch 00011: val_loss did not improve from 0.00794
# Epoch 12/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0019 - mae: 0.0297 - val_loss: 0.0081 - val_mae: 0.0611
#
# Epoch 00012: val_loss did not improve from 0.00794
# Epoch 13/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0018 - mae: 0.0292 - val_loss: 0.0080 - val_mae: 0.0639
#
# Epoch 00013: val_loss did not improve from 0.00794
# Epoch 14/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0018 - mae: 0.0292 - val_loss: 0.0078 - val_mae: 0.0601
#
# Epoch 00014: val_loss improved from 0.00794 to 0.00776, saving model to model/aaa
# Epoch 15/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0018 - mae: 0.0290 - val_loss: 0.0076 - val_mae: 0.0634
#
# Epoch 00015: val_loss improved from 0.00776 to 0.00760, saving model to model/aaa
# Epoch 16/50
# 49522/49522 [==============================] - 64s 1ms/step - loss: 0.0018 - mae: 0.0286 - val_loss: 0.0086 - val_mae: 0.0638
#
# Epoch 00016: val_loss did not improve from 0.00760
# Epoch 17/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0017 - mae: 0.0282 - val_loss: 0.0082 - val_mae: 0.0601
#
# Epoch 00017: val_loss did not improve from 0.00760
# Epoch 18/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0016 - mae: 0.0276 - val_loss: 0.0076 - val_mae: 0.0595
#
# Epoch 00018: val_loss improved from 0.00760 to 0.00756, saving model to model/aaa
# Epoch 19/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0016 - mae: 0.0275 - val_loss: 0.0074 - val_mae: 0.0590
#
# Epoch 00019: val_loss improved from 0.00756 to 0.00736, saving model to model/aaa
# Epoch 20/50
# 49522/49522 [==============================] - 64s 1ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0074 - val_mae: 0.0598
#
# Epoch 00020: val_loss improved from 0.00736 to 0.00735, saving model to model/aaa
# Epoch 21/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0015 - mae: 0.0268 - val_loss: 0.0098 - val_mae: 0.0689
#
# Epoch 00021: val_loss did not improve from 0.00735
# Epoch 22/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0015 - mae: 0.0264 - val_loss: 0.0075 - val_mae: 0.0596
#
# Epoch 00022: val_loss did not improve from 0.00735
# Epoch 23/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0079 - val_mae: 0.0579
#
# Epoch 00023: val_loss did not improve from 0.00735
# Epoch 24/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 0.0081 - val_mae: 0.0605
#
# Epoch 00024: val_loss did not improve from 0.00735
# Epoch 25/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0014 - mae: 0.0256 - val_loss: 0.0072 - val_mae: 0.0580
#
# Epoch 00025: val_loss improved from 0.00735 to 0.00718, saving model to model/aaa
# Epoch 26/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0014 - mae: 0.0255 - val_loss: 0.0078 - val_mae: 0.0577
#
# Epoch 00026: val_loss did not improve from 0.00718
# Epoch 27/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0014 - mae: 0.0254 - val_loss: 0.0071 - val_mae: 0.0580
#
# Epoch 00027: val_loss improved from 0.00718 to 0.00712, saving model to model/aaa
# Epoch 28/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0014 - mae: 0.0252 - val_loss: 0.0074 - val_mae: 0.0580
#
# Epoch 00028: val_loss did not improve from 0.00712
# Epoch 29/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0013 - mae: 0.0250 - val_loss: 0.0087 - val_mae: 0.0632
#
# Epoch 00029: val_loss did not improve from 0.00712
# Epoch 30/50
# 49522/49522 [==============================] - 66s 1ms/step - loss: 0.0013 - mae: 0.0249 - val_loss: 0.0083 - val_mae: 0.0595
#
# Epoch 00030: val_loss did not improve from 0.00712
# Epoch 31/50
# 49522/49522 [==============================] - 64s 1ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0081 - val_mae: 0.0602
#
# Epoch 00031: val_loss did not improve from 0.00712
# Epoch 32/50
# 49522/49522 [==============================] - 65s 1ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0084 - val_mae: 0.0608
#
# Epoch 00032: val_loss did not improve from 0.00712
# 61903/61903 [==============================] - 42s 676us/step

# %%
# calculate Pearson's correlation
y_pred = model.predict(x, verbose=1)

import math
def calcMean(x,y):
    sum_x = sum(x)
    sum_y = sum(y)
    n = len(x)
    x_mean = float(sum_x+0.0)/n
    y_mean = float(sum_y+0.0)/n
    return x_mean,y_mean

def calcPearson(x,y):
    x_mean,y_mean = calcMean(x,y)
    n = len(x)
    sumTop = 0.0
    sumBottom = 0.0
    x_pow = 0.0
    y_pow = 0.0
    for i in range(n):
        sumTop += (x[i]-x_mean)*(y[i]-y_mean)
    for i in range(n):
        x_pow += math.pow(x[i]-x_mean,2)
    for i in range(n):
        y_pow += math.pow(y[i]-y_mean,2)
    sumBottom = math.sqrt(x_pow*y_pow)
    p = sumTop/sumBottom
    return p

Pearson = calcPearson(y, y_pred)
print(Pearson)
# Out:
# 61903/61903 [==============================] - 41s 666us/step
# [0.9132044]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

font = {'size': 15}
plt.figure(figsize=(5,5))
plt.xlim(0,0.7)
plt.ylim(0,0.7)
plt.xlabel('Observed', font)
plt.ylabel('Predicted', font)
plt.grid(True)
plt.scatter(y[:10000], y_pred[:10000], c='r', alpha=0.1, label='Pearson r = %0.3f' % Pearson)
plt.legend(loc=1, fontsize='x-large')
plt.show()
